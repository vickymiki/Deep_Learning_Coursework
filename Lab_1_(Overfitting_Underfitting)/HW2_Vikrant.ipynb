# %% [markdown]
# # Homework Assignment 2: Deep Learning Foundation

# %% [markdown]
# <div class="alert alert-block alert-warning">Each assignment needs to be completed independently. Never ever copy others' work (even with minor modification, e.g. changing variable names). Anti-Plagiarism software will be used to check all submissions. </div>

# %% [markdown]
# ## Objectives:
#
#
# - Start to learn PyTorch programming
# - Practice creating sequential models with PyTorch
# - Learn techniques to fight with underfitting and overfitting
#     - Layer configuration
#     - Regularizers
#     - Optimizers

# %% [markdown]
# ## Instructions
#
#
# - Check `Lab 2: Overfitting_Underfitting` before you start working on this assignment. These labs should give you a good starting point.
# - Please complete all questions using Jupyter Notebook.
# - Please answer all analysis questions using Jupyter Notebook Markdowns or in a separate pdf file (if you don't know how to write Markdowns).
# - Please run your Jupyter Notebook to get all training histories and plots, save the notebook to pdf file, and sumbit the pdf file along with the Jupyter Notebook

# %% [markdown]
# ## The FashionMNIST dataset
#
# -  `FashionMNIST`, a dataset of article images—consisting of a training set of 60,000 examples and a test set of 10,000 examples. Each example is a 28x28 grayscale image, associated with a label from 10 classes. For details, check https://github.com/zalandoresearch/fashion-mnist
# - To reduce the training time, `we'll only use 6000 images for training`
# - See code below to load dataset

# %%
 pip install torchinfo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchinfo
#   Downloading torchinfo-1.7.0-py3-none-any.whl (22 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.7.0

# %%
from IPython.core.interactiveshell import InteractiveShell 

InteractiveShell.ast_node_interactivity = "all"

import pandas as pd
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import DataLoader, random_split, Subset
import torchvision.transforms as transforms

import torchvision

from numpy.random import seed
import torch
import numpy as np

from torchinfo import summary
import matplotlib.pyplot as plt

# %%
# Load dataset

train_dataset = torchvision.datasets.FashionMNIST('./data',
                                           train=True,
                                           transform=transforms.ToTensor(),
                                           download=True)

test_dataset = torchvision.datasets.FashionMNIST('./data',
                                          train=False,
                                          transform=transforms.ToTensor(),
                                          download=True)
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/26421880 [00:00<?, ?it/s]
# Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/29515 [00:00<?, ?it/s]
# Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/4422102 [00:00<?, ?it/s]
# Extracting ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/5148 [00:00<?, ?it/s]
# Extracting ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw

# %%
# Randomly select 6000 for training

N = len(train_dataset)
train_dataset = Subset(train_dataset, np.random.choice(N, 6000, replace=False))

# %%
# Split dataset into training and evaluation

N = len(train_dataset)
train_size = int(0.7*N)
train_dataset, val_dataset = random_split(train_dataset,\
                                          lengths=[train_size, N - train_size])

print(f'Train dataset length: {len(train_dataset)}')
print(f'Validation dataset length: {len(val_dataset)}')
# Out:
# Train dataset length: 4200
# Validation dataset length: 1800

# %%
# Show some images from test dataset

batch_size = 32

test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
imgs, labels = next(iter(test_loader))
plt.figure(figsize=(15,10))
grid = torchvision.utils.make_grid(nrow=16, ncols=2, tensor=imgs)
print(f"image tensor: {imgs.shape}")
print(f"class labels: {labels}")
plt.imshow(np.transpose(grid, axes=(1,2,0)), cmap='gray');
# Out:
# image tensor: torch.Size([32, 1, 28, 28])
# class labels: tensor([9, 2, 1, 1, 6, 1, 4, 6, 5, 7, 4, 5, 7, 3, 4, 1, 2, 4, 8, 0, 2, 5, 7, 9,
#         1, 4, 6, 0, 9, 3, 8, 8])

# %% [markdown]
# ## Q1: Create a simple model with only 1 hidden linear layer (6 points)
#
# 1. **Model A**: Create a simple feedforward model as follows: `(2 points)`
#     - The model has `1 hidden layer`. In your first configuration, you can `configure this linear layer to have 64 units`. You need to choose a right activation function for this hidden layer
#     - Add the output layer. Be sure to set the right number of units and activation function for this ouputput layer.
#  <br><br>
#
# 2. Define a function `fit_model(model, train_dataset, eval_dataset, test_dataset, device, optimizer, epochs=30, batch_size=128)`, and use this function to train the model as follows: `(1 point)`
#     - Create a dataload for each dataset to get mini-batches
#     - You need to `flatten each image (shape of (1, 28, 28)) to (784,)` so that it can enter the hidden layer.
#     - Train the model using `train_dataset`, evaluate model loss and accuracy using `eval_dataset`, and record the evaluation loss and accuracy history.
#     - When training completes, test the model using `test_dataset`, and calculate the `test accuracy`. `(deduct 0.5 if testing accuracy is not calcuated)`
#     - Return test accuracy, and evaluation loss and accuracy histories
# <br><br>
# 3. When you train the model, you'll need to tune the following hyperparameters. Here are suggested values for some parameters for you to get started:
#     - optimizer: RMSProp
#     - loss: `pick a right loss function` from this list: https://pytorch.org/docs/stable/nn.html#loss-functions
#     - batch_size: 128 (this depends on the CPU/GPU of your computer)
#     - epoch: 100
#     - learning rate: 0.0005
# <br><br>
# 4.  **Model B**: After you complete training your Model A, now you can configure the hidden layer by gradually increasing or decreasing the number of units. Your taget is to improve the evaluation/test accuracy by at least 1%. `(1 point. Deduct 0.5 if testing accuracy is not improved by 1%)`
# <br><br>
# 5. Plot evaluation loss / accuracy vs. epoches for these two models `(1 point, deduct 0.5 if test accuracy is below 80%)`
#     - Reference plots are provided. You may generate different plots.
#     - In general, the evaluation and test accuracy of this problem should be `80%-84%`.
#  <br><br>
# 6. Write your analysis (as markdowns or a seperate pdf file) on the following: `(1 point)`
#    - How many parametes does each model has? `(0.3 point)`: *see model summary*
#    - For each model, do you observe underfitting or overfitting? `(0.3 point)`: *underfitting can be seen in about epochs 0-20. Model B has overfitted slightly after epoch 60 but not much in Model A*
#    - Which model in general performs better than the other in terms of evaluation loss / accuracy? Explain why this model outperforms the other. `(0.4 point)`: *Model B has slightly higher evaluation accuracy and lower evaluation loss. This is due to increased hidden units and model capacity*.

# %%
# Fix random number so that your traing process can be replicated

random_seed = 124
seed(random_seed)

torch.manual_seed(random_seed)
torch.backends.cudnn.deterministic = True

# %%
class linear_model(nn.Module):
    
    # hidden_units is a list which specify the output of each layer
    def __init__(self, input_dim = 784, hidden_units=[256]):
        
        # initialize parent class
        super(linear_model, self).__init__()
        
        hidden_units = [input_dim] + hidden_units
        
        self.layers = nn.ModuleList([nn.Linear(hidden_units[i], hidden_units[i+1]) \
                                     for i in range(len(hidden_units)-1)])
    
    def forward(self, x):
        
        output = x
        #print(x.size())
        for i, layer in enumerate(self.layers):
            
            output = layer(output)
            #print(output.size())
            
            if i<len(self.layers)-1:   # no activation on the last layer
                output = F.relu(output)
        
        return output

# %%
def train_model(model, train_dataset, val_dataset, test_dataset, device, 
                optimizer, epochs=30, batch_size=128):
    
    # construct dataloader
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
    
    # move model to device
    model = model.to(device)

    # history
    history = {'train_loss': [],
               'train_acc': [],
               'val_loss': [],
               'val_acc': []}

    # setup loss function and optimizer
    criterion = nn.CrossEntropyLoss()
    #optimizer = torch.optim.SGD(model.parameters(), lr=lr)

    # training loop
    print('Training Start')
    for epoch in range(epochs):
        model.train()
        train_loss = 0
        train_acc = 0
        val_loss = 0
        val_acc = 0
        
        for x, y in train_loader:
            
            # move data to device
            x = x.view(x.size(0), -1).to(device)
            y = y.to(device)
            
            # forward
            outputs = model(x)  # (num_batch, 45) 
            _, pred = torch.max(outputs, dim = -1)
            cur_train_loss = criterion(outputs, y)
            cur_train_acc = (pred == y).sum().item() / y.size(0)
            
            # backward
            cur_train_loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            
            # loss and acc
            train_loss += cur_train_loss
            train_acc += cur_train_acc

        # test start
        model.eval()
        with torch.no_grad():
            for x, y in val_loader:
                # move
                x = x.view(x.size(0), -1).to(device)
                y = y.to(device)
                
                # predict
                outputs = model(x)
                _, pred = torch.max(outputs, dim = -1)
                cur_val_loss = criterion(outputs, y)
                cur_val_acc = (pred == y).sum().item() / y.size(0) 
                
                # loss and acc
                val_loss += cur_val_loss
                val_acc += cur_val_acc

        # epoch output
        train_loss = (train_loss/len(train_loader)).item()
        train_acc = train_acc/len(train_loader)
        val_loss = (val_loss/len(val_loader)).item()
        val_acc = val_acc/len(val_loader)
        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_acc)
        history['val_loss'].append(val_loss)
        history['val_acc'].append(val_acc)
        print(f"Epoch:{epoch + 1} / {epochs}, train loss:{train_loss:.3f} train_acc:{train_acc:.3f}, valid loss:{val_loss:.3f} valid acc:{val_acc:.3f}")
    
    # Test performance
    model.eval()
    ys = []
    preds = []

    with torch.no_grad():
        for x, y in test_loader:
            # move
            x = x.view(x.size(0), -1).to(device)

            # predict
            outputs = model(x)
            _, pred = torch.max(outputs, dim = -1)

            preds.append(pred.view(-1).cpu().numpy())
            ys.append(y)

    ys = np.concatenate(ys)
    preds = np.concatenate(preds)

    test_acc = (ys==preds).astype(int).sum()/len(ys)
    print(f"test acc:{test_acc:.3f}")

    return test_acc, history

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# dataset

modela = linear_model(input_dim = 784, hidden_units=[64,  10])
summary(modela, (32, 784))

optimizer = torch.optim.RMSprop(modela.parameters(), lr = 0.0005)
acc_a, hista = train_model(modela, train_dataset, val_dataset, test_dataset, device, optimizer, epochs=100)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# linear_model                             [32, 10]                  --
# ├─ModuleList: 1-1                        --                        --
# │    └─Linear: 2-1                       [32, 64]                  50,240
# │    └─Linear: 2-2                       [32, 10]                  650
# ==========================================================================================
# Total params: 50,890
# Trainable params: 50,890
# Non-trainable params: 0
# Total mult-adds (M): 1.63
# ==========================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 0.02
# Params size (MB): 0.20
# Estimated Total Size (MB): 0.32
# ==========================================================================================
# Training Start
# Epoch:1 / 100, train loss:1.243 train_acc:0.604, valid loss:0.827 valid acc:0.741
# Epoch:2 / 100, train loss:0.813 train_acc:0.736, valid loss:0.700 valid acc:0.763
# Epoch:3 / 100, train loss:0.711 train_acc:0.771, valid loss:0.631 valid acc:0.798
# Epoch:4 / 100, train loss:0.655 train_acc:0.781, valid loss:0.600 valid acc:0.821
# Epoch:5 / 100, train loss:0.617 train_acc:0.791, valid loss:0.585 valid acc:0.812
# Epoch:6 / 100, train loss:0.590 train_acc:0.804, valid loss:0.580 valid acc:0.805
# Epoch:7 / 100, train loss:0.565 train_acc:0.809, valid loss:0.536 valid acc:0.823
# Epoch:8 / 100, train loss:0.549 train_acc:0.812, valid loss:0.518 valid acc:0.827
# Epoch:9 / 100, train loss:0.531 train_acc:0.818, valid loss:0.503 valid acc:0.837
# Epoch:10 / 100, train loss:0.515 train_acc:0.822, valid loss:0.497 valid acc:0.842
# Epoch:11 / 100, train loss:0.504 train_acc:0.823, valid loss:0.493 valid acc:0.840
# Epoch:12 / 100, train loss:0.487 train_acc:0.834, valid loss:0.476 valid acc:0.848
# Epoch:13 / 100, train loss:0.482 train_acc:0.833, valid loss:0.477 valid acc:0.843
# Epoch:14 / 100, train loss:0.467 train_acc:0.836, valid loss:0.465 valid acc:0.845
# Epoch:15 / 100, train loss:0.459 train_acc:0.842, valid loss:0.462 valid acc:0.844
# Epoch:16 / 100, train loss:0.451 train_acc:0.844, valid loss:0.460 valid acc:0.844
# Epoch:17 / 100, train loss:0.444 train_acc:0.841, valid loss:0.459 valid acc:0.855
# Epoch:18 / 100, train loss:0.438 train_acc:0.849, valid loss:0.458 valid acc:0.849
# Epoch:19 / 100, train loss:0.428 train_acc:0.850, valid loss:0.470 valid acc:0.848
# Epoch:20 / 100, train loss:0.421 train_acc:0.855, valid loss:0.442 valid acc:0.853
# Epoch:21 / 100, train loss:0.417 train_acc:0.854, valid loss:0.448 valid acc:0.849
# Epoch:22 / 100, train loss:0.412 train_acc:0.854, valid loss:0.437 valid acc:0.852
# Epoch:23 / 100, train loss:0.404 train_acc:0.855, valid loss:0.448 valid acc:0.846
# Epoch:24 / 100, train loss:0.398 train_acc:0.861, valid loss:0.458 valid acc:0.845
# Epoch:25 / 100, train loss:0.392 train_acc:0.861, valid loss:0.435 valid acc:0.851
# Epoch:26 / 100, train loss:0.391 train_acc:0.861, valid loss:0.438 valid acc:0.852
# Epoch:27 / 100, train loss:0.380 train_acc:0.871, valid loss:0.435 valid acc:0.849
# Epoch:28 / 100, train loss:0.382 train_acc:0.867, valid loss:0.440 valid acc:0.856
# Epoch:29 / 100, train loss:0.378 train_acc:0.869, valid loss:0.442 valid acc:0.846
# Epoch:30 / 100, train loss:0.368 train_acc:0.871, valid loss:0.427 valid acc:0.856
# Epoch:31 / 100, train loss:0.364 train_acc:0.876, valid loss:0.427 valid acc:0.853
# Epoch:32 / 100, train loss:0.358 train_acc:0.877, valid loss:0.440 valid acc:0.849
# Epoch:33 / 100, train loss:0.356 train_acc:0.872, valid loss:0.431 valid acc:0.849
# Epoch:34 / 100, train loss:0.351 train_acc:0.882, valid loss:0.451 valid acc:0.846
# Epoch:35 / 100, train loss:0.348 train_acc:0.883, valid loss:0.449 valid acc:0.848
# Epoch:36 / 100, train loss:0.345 train_acc:0.876, valid loss:0.444 valid acc:0.848
# Epoch:37 / 100, train loss:0.344 train_acc:0.879, valid loss:0.429 valid acc:0.852
# Epoch:38 / 100, train loss:0.338 train_acc:0.884, valid loss:0.424 valid acc:0.854
# Epoch:39 / 100, train loss:0.334 train_acc:0.883, valid loss:0.420 valid acc:0.858
# Epoch:40 / 100, train loss:0.328 train_acc:0.889, valid loss:0.419 valid acc:0.854
# Epoch:41 / 100, train loss:0.328 train_acc:0.885, valid loss:0.427 valid acc:0.851
# Epoch:42 / 100, train loss:0.321 train_acc:0.893, valid loss:0.421 valid acc:0.858
# Epoch:43 / 100, train loss:0.318 train_acc:0.892, valid loss:0.439 valid acc:0.852
# Epoch:44 / 100, train loss:0.316 train_acc:0.892, valid loss:0.421 valid acc:0.859
# Epoch:45 / 100, train loss:0.311 train_acc:0.895, valid loss:0.431 valid acc:0.856
# Epoch:46 / 100, train loss:0.312 train_acc:0.893, valid loss:0.430 valid acc:0.856
# Epoch:47 / 100, train loss:0.309 train_acc:0.895, valid loss:0.423 valid acc:0.858
# Epoch:48 / 100, train loss:0.302 train_acc:0.899, valid loss:0.440 valid acc:0.852
# Epoch:49 / 100, train loss:0.301 train_acc:0.897, valid loss:0.437 valid acc:0.852
# Epoch:50 / 100, train loss:0.298 train_acc:0.898, valid loss:0.446 valid acc:0.850
# Epoch:51 / 100, train loss:0.296 train_acc:0.899, valid loss:0.496 valid acc:0.824
# Epoch:52 / 100, train loss:0.294 train_acc:0.901, valid loss:0.443 valid acc:0.845
# Epoch:53 / 100, train loss:0.290 train_acc:0.902, valid loss:0.428 valid acc:0.853
# Epoch:54 / 100, train loss:0.290 train_acc:0.898, valid loss:0.434 valid acc:0.855
# Epoch:55 / 100, train loss:0.285 train_acc:0.903, valid loss:0.426 valid acc:0.852
# Epoch:56 / 100, train loss:0.281 train_acc:0.907, valid loss:0.425 valid acc:0.857
# Epoch:57 / 100, train loss:0.279 train_acc:0.906, valid loss:0.421 valid acc:0.854
# Epoch:58 / 100, train loss:0.277 train_acc:0.908, valid loss:0.427 valid acc:0.859
# Epoch:59 / 100, train loss:0.274 train_acc:0.911, valid loss:0.434 valid acc:0.854
# Epoch:60 / 100, train loss:0.270 train_acc:0.908, valid loss:0.436 valid acc:0.852
# Epoch:61 / 100, train loss:0.269 train_acc:0.910, valid loss:0.453 valid acc:0.850
# Epoch:62 / 100, train loss:0.268 train_acc:0.912, valid loss:0.444 valid acc:0.851
# Epoch:63 / 100, train loss:0.266 train_acc:0.912, valid loss:0.428 valid acc:0.854
# Epoch:64 / 100, train loss:0.262 train_acc:0.914, valid loss:0.422 valid acc:0.858
# Epoch:65 / 100, train loss:0.258 train_acc:0.915, valid loss:0.474 valid acc:0.844
# Epoch:66 / 100, train loss:0.256 train_acc:0.915, valid loss:0.420 valid acc:0.857
# Epoch:67 / 100, train loss:0.253 train_acc:0.916, valid loss:0.431 valid acc:0.855
# Epoch:68 / 100, train loss:0.252 train_acc:0.917, valid loss:0.432 valid acc:0.850
# Epoch:69 / 100, train loss:0.255 train_acc:0.915, valid loss:0.448 valid acc:0.855
# Epoch:70 / 100, train loss:0.248 train_acc:0.919, valid loss:0.434 valid acc:0.846
# Epoch:71 / 100, train loss:0.243 train_acc:0.920, valid loss:0.453 valid acc:0.852
# Epoch:72 / 100, train loss:0.242 train_acc:0.919, valid loss:0.448 valid acc:0.848
# Epoch:73 / 100, train loss:0.241 train_acc:0.921, valid loss:0.447 valid acc:0.854
# Epoch:74 / 100, train loss:0.243 train_acc:0.921, valid loss:0.439 valid acc:0.856
# Epoch:75 / 100, train loss:0.239 train_acc:0.921, valid loss:0.462 valid acc:0.851
# Epoch:76 / 100, train loss:0.237 train_acc:0.923, valid loss:0.444 valid acc:0.852
# Epoch:77 / 100, train loss:0.234 train_acc:0.925, valid loss:0.444 valid acc:0.853
# Epoch:78 / 100, train loss:0.230 train_acc:0.921, valid loss:0.435 valid acc:0.854
# Epoch:79 / 100, train loss:0.227 train_acc:0.925, valid loss:0.441 valid acc:0.853
# Epoch:80 / 100, train loss:0.236 train_acc:0.921, valid loss:0.433 valid acc:0.855
# Epoch:81 / 100, train loss:0.226 train_acc:0.926, valid loss:0.438 valid acc:0.852
# Epoch:82 / 100, train loss:0.224 train_acc:0.929, valid loss:0.458 valid acc:0.849
# Epoch:83 / 100, train loss:0.222 train_acc:0.927, valid loss:0.450 valid acc:0.852
# Epoch:84 / 100, train loss:0.219 train_acc:0.932, valid loss:0.449 valid acc:0.854
# Epoch:85 / 100, train loss:0.220 train_acc:0.928, valid loss:0.452 valid acc:0.855
# Epoch:86 / 100, train loss:0.220 train_acc:0.924, valid loss:0.454 valid acc:0.855
# Epoch:87 / 100, train loss:0.217 train_acc:0.929, valid loss:0.440 valid acc:0.855
# Epoch:88 / 100, train loss:0.209 train_acc:0.935, valid loss:0.443 valid acc:0.855
# Epoch:89 / 100, train loss:0.207 train_acc:0.934, valid loss:0.454 valid acc:0.852
# Epoch:90 / 100, train loss:0.211 train_acc:0.931, valid loss:0.443 valid acc:0.855
# Epoch:91 / 100, train loss:0.208 train_acc:0.933, valid loss:0.447 valid acc:0.860
# Epoch:92 / 100, train loss:0.213 train_acc:0.926, valid loss:0.453 valid acc:0.853
# Epoch:93 / 100, train loss:0.208 train_acc:0.932, valid loss:0.456 valid acc:0.856
# Epoch:94 / 100, train loss:0.205 train_acc:0.933, valid loss:0.450 valid acc:0.855
# Epoch:95 / 100, train loss:0.200 train_acc:0.939, valid loss:0.464 valid acc:0.848
# Epoch:96 / 100, train loss:0.198 train_acc:0.937, valid loss:0.449 valid acc:0.854
# Epoch:97 / 100, train loss:0.199 train_acc:0.934, valid loss:0.453 valid acc:0.857
# Epoch:98 / 100, train loss:0.201 train_acc:0.932, valid loss:0.459 valid acc:0.856
# Epoch:99 / 100, train loss:0.196 train_acc:0.937, valid loss:0.449 valid acc:0.855
# Epoch:100 / 100, train loss:0.194 train_acc:0.938, valid loss:0.497 valid acc:0.843
# test acc:0.818

# %%
# dataset

modelb = linear_model(input_dim = 784, hidden_units=[512,  10])
summary(modelb, (32, 784))

optimizer = torch.optim.RMSprop(modelb.parameters(), lr = 0.0005)
acc_b, histb = train_model(modelb, train_dataset, val_dataset, test_dataset, device, optimizer, epochs = 100)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# linear_model                             [32, 10]                  --
# ├─ModuleList: 1-1                        --                        --
# │    └─Linear: 2-1                       [32, 512]                 401,920
# │    └─Linear: 2-2                       [32, 10]                  5,130
# ==========================================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# Total mult-adds (M): 13.03
# ==========================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 0.13
# Params size (MB): 1.63
# Estimated Total Size (MB): 1.86
# ==========================================================================================
# Training Start
# Epoch:1 / 100, train loss:1.083 train_acc:0.618, valid loss:0.679 valid acc:0.776
# Epoch:2 / 100, train loss:0.680 train_acc:0.765, valid loss:0.575 valid acc:0.807
# Epoch:3 / 100, train loss:0.603 train_acc:0.785, valid loss:0.516 valid acc:0.824
# Epoch:4 / 100, train loss:0.543 train_acc:0.811, valid loss:0.515 valid acc:0.815
# Epoch:5 / 100, train loss:0.514 train_acc:0.814, valid loss:0.515 valid acc:0.820
# Epoch:6 / 100, train loss:0.487 train_acc:0.828, valid loss:0.479 valid acc:0.843
# Epoch:7 / 100, train loss:0.469 train_acc:0.832, valid loss:0.502 valid acc:0.830
# Epoch:8 / 100, train loss:0.457 train_acc:0.838, valid loss:0.457 valid acc:0.846
# Epoch:9 / 100, train loss:0.438 train_acc:0.842, valid loss:0.439 valid acc:0.848
# Epoch:10 / 100, train loss:0.412 train_acc:0.856, valid loss:0.462 valid acc:0.837
# Epoch:11 / 100, train loss:0.399 train_acc:0.855, valid loss:0.442 valid acc:0.847
# Epoch:12 / 100, train loss:0.394 train_acc:0.856, valid loss:0.432 valid acc:0.844
# Epoch:13 / 100, train loss:0.386 train_acc:0.864, valid loss:0.430 valid acc:0.852
# Epoch:14 / 100, train loss:0.369 train_acc:0.871, valid loss:0.406 valid acc:0.857
# Epoch:15 / 100, train loss:0.353 train_acc:0.877, valid loss:0.466 valid acc:0.831
# Epoch:16 / 100, train loss:0.337 train_acc:0.879, valid loss:0.398 valid acc:0.852
# Epoch:17 / 100, train loss:0.321 train_acc:0.892, valid loss:0.442 valid acc:0.848
# Epoch:18 / 100, train loss:0.329 train_acc:0.882, valid loss:0.416 valid acc:0.860
# Epoch:19 / 100, train loss:0.314 train_acc:0.890, valid loss:0.418 valid acc:0.852
# Epoch:20 / 100, train loss:0.312 train_acc:0.888, valid loss:0.396 valid acc:0.856
# Epoch:21 / 100, train loss:0.299 train_acc:0.892, valid loss:0.427 valid acc:0.858
# Epoch:22 / 100, train loss:0.290 train_acc:0.895, valid loss:0.434 valid acc:0.846
# Epoch:23 / 100, train loss:0.287 train_acc:0.901, valid loss:0.395 valid acc:0.857
# Epoch:24 / 100, train loss:0.279 train_acc:0.906, valid loss:0.397 valid acc:0.853
# Epoch:25 / 100, train loss:0.268 train_acc:0.907, valid loss:0.397 valid acc:0.859
# Epoch:26 / 100, train loss:0.257 train_acc:0.911, valid loss:0.422 valid acc:0.856
# Epoch:27 / 100, train loss:0.257 train_acc:0.911, valid loss:0.417 valid acc:0.864
# Epoch:28 / 100, train loss:0.256 train_acc:0.911, valid loss:0.448 valid acc:0.845
# Epoch:29 / 100, train loss:0.244 train_acc:0.918, valid loss:0.468 valid acc:0.833
# Epoch:30 / 100, train loss:0.248 train_acc:0.913, valid loss:0.422 valid acc:0.856
# Epoch:31 / 100, train loss:0.228 train_acc:0.921, valid loss:0.396 valid acc:0.860
# Epoch:32 / 100, train loss:0.223 train_acc:0.926, valid loss:0.425 valid acc:0.856
# Epoch:33 / 100, train loss:0.218 train_acc:0.926, valid loss:0.530 valid acc:0.820
# Epoch:34 / 100, train loss:0.210 train_acc:0.929, valid loss:0.437 valid acc:0.848
# Epoch:35 / 100, train loss:0.208 train_acc:0.930, valid loss:0.414 valid acc:0.851
# Epoch:36 / 100, train loss:0.207 train_acc:0.928, valid loss:0.391 valid acc:0.866
# Epoch:37 / 100, train loss:0.193 train_acc:0.937, valid loss:0.444 valid acc:0.851
# Epoch:38 / 100, train loss:0.192 train_acc:0.935, valid loss:0.548 valid acc:0.807
# Epoch:39 / 100, train loss:0.196 train_acc:0.932, valid loss:0.402 valid acc:0.854
# Epoch:40 / 100, train loss:0.176 train_acc:0.941, valid loss:0.421 valid acc:0.865
# Epoch:41 / 100, train loss:0.187 train_acc:0.939, valid loss:0.429 valid acc:0.859
# Epoch:42 / 100, train loss:0.174 train_acc:0.937, valid loss:0.411 valid acc:0.861
# Epoch:43 / 100, train loss:0.163 train_acc:0.949, valid loss:0.396 valid acc:0.866
# Epoch:44 / 100, train loss:0.167 train_acc:0.945, valid loss:0.418 valid acc:0.860
# Epoch:45 / 100, train loss:0.158 train_acc:0.950, valid loss:0.429 valid acc:0.855
# Epoch:46 / 100, train loss:0.164 train_acc:0.947, valid loss:0.423 valid acc:0.859
# Epoch:47 / 100, train loss:0.157 train_acc:0.949, valid loss:0.411 valid acc:0.861
# Epoch:48 / 100, train loss:0.146 train_acc:0.953, valid loss:0.432 valid acc:0.864
# Epoch:49 / 100, train loss:0.146 train_acc:0.949, valid loss:0.405 valid acc:0.864
# Epoch:50 / 100, train loss:0.137 train_acc:0.955, valid loss:0.424 valid acc:0.866
# Epoch:51 / 100, train loss:0.143 train_acc:0.953, valid loss:0.508 valid acc:0.845
# Epoch:52 / 100, train loss:0.139 train_acc:0.954, valid loss:0.419 valid acc:0.866
# Epoch:53 / 100, train loss:0.154 train_acc:0.947, valid loss:0.416 valid acc:0.867
# Epoch:54 / 100, train loss:0.122 train_acc:0.962, valid loss:0.436 valid acc:0.863
# Epoch:55 / 100, train loss:0.127 train_acc:0.959, valid loss:0.431 valid acc:0.864
# Epoch:56 / 100, train loss:0.120 train_acc:0.964, valid loss:0.441 valid acc:0.857
# Epoch:57 / 100, train loss:0.118 train_acc:0.964, valid loss:0.442 valid acc:0.865
# Epoch:58 / 100, train loss:0.124 train_acc:0.961, valid loss:0.433 valid acc:0.861
# Epoch:59 / 100, train loss:0.106 train_acc:0.970, valid loss:0.432 valid acc:0.868
# Epoch:60 / 100, train loss:0.107 train_acc:0.968, valid loss:0.452 valid acc:0.865
# Epoch:61 / 100, train loss:0.114 train_acc:0.960, valid loss:0.456 valid acc:0.860
# Epoch:62 / 100, train loss:0.106 train_acc:0.968, valid loss:0.434 valid acc:0.870
# Epoch:63 / 100, train loss:0.108 train_acc:0.966, valid loss:0.446 valid acc:0.863
# Epoch:64 / 100, train loss:0.102 train_acc:0.972, valid loss:0.439 valid acc:0.869
# Epoch:65 / 100, train loss:0.094 train_acc:0.974, valid loss:0.436 valid acc:0.868
# Epoch:66 / 100, train loss:0.094 train_acc:0.971, valid loss:0.457 valid acc:0.869
# Epoch:67 / 100, train loss:0.100 train_acc:0.969, valid loss:0.472 valid acc:0.863
# Epoch:68 / 100, train loss:0.092 train_acc:0.973, valid loss:0.462 valid acc:0.861
# Epoch:69 / 100, train loss:0.092 train_acc:0.972, valid loss:0.458 valid acc:0.872
# Epoch:70 / 100, train loss:0.078 train_acc:0.977, valid loss:0.452 valid acc:0.871
# Epoch:71 / 100, train loss:0.081 train_acc:0.976, valid loss:0.502 valid acc:0.858
# Epoch:72 / 100, train loss:0.083 train_acc:0.974, valid loss:0.463 valid acc:0.866
# Epoch:73 / 100, train loss:0.087 train_acc:0.970, valid loss:0.466 valid acc:0.870
# Epoch:74 / 100, train loss:0.072 train_acc:0.980, valid loss:0.555 valid acc:0.856
# Epoch:75 / 100, train loss:0.082 train_acc:0.975, valid loss:0.449 valid acc:0.865
# Epoch:76 / 100, train loss:0.070 train_acc:0.980, valid loss:0.476 valid acc:0.868
# Epoch:77 / 100, train loss:0.069 train_acc:0.979, valid loss:0.487 valid acc:0.858
# Epoch:78 / 100, train loss:0.073 train_acc:0.981, valid loss:0.469 valid acc:0.870
# Epoch:79 / 100, train loss:0.060 train_acc:0.986, valid loss:0.493 valid acc:0.861
# Epoch:80 / 100, train loss:0.067 train_acc:0.979, valid loss:0.479 valid acc:0.867
# Epoch:81 / 100, train loss:0.078 train_acc:0.981, valid loss:0.473 valid acc:0.867
# Epoch:82 / 100, train loss:0.071 train_acc:0.979, valid loss:0.518 valid acc:0.859
# Epoch:83 / 100, train loss:0.059 train_acc:0.982, valid loss:0.497 valid acc:0.864
# Epoch:84 / 100, train loss:0.060 train_acc:0.983, valid loss:0.496 valid acc:0.863
# Epoch:85 / 100, train loss:0.058 train_acc:0.984, valid loss:0.523 valid acc:0.860
# Epoch:86 / 100, train loss:0.062 train_acc:0.985, valid loss:0.516 valid acc:0.866
# Epoch:87 / 100, train loss:0.067 train_acc:0.979, valid loss:0.597 valid acc:0.851
# Epoch:88 / 100, train loss:0.053 train_acc:0.987, valid loss:0.527 valid acc:0.862
# Epoch:89 / 100, train loss:0.045 train_acc:0.989, valid loss:0.689 valid acc:0.838
# Epoch:90 / 100, train loss:0.057 train_acc:0.984, valid loss:0.516 valid acc:0.870
# Epoch:91 / 100, train loss:0.046 train_acc:0.989, valid loss:0.503 valid acc:0.870
# Epoch:92 / 100, train loss:0.055 train_acc:0.985, valid loss:0.506 valid acc:0.868
# Epoch:93 / 100, train loss:0.054 train_acc:0.986, valid loss:0.508 valid acc:0.867
# Epoch:94 / 100, train loss:0.036 train_acc:0.993, valid loss:0.563 valid acc:0.856
# Epoch:95 / 100, train loss:0.045 train_acc:0.986, valid loss:0.525 valid acc:0.866
# Epoch:96 / 100, train loss:0.042 train_acc:0.991, valid loss:0.539 valid acc:0.861
# Epoch:97 / 100, train loss:0.097 train_acc:0.973, valid loss:0.502 valid acc:0.867
# Epoch:98 / 100, train loss:0.036 train_acc:0.993, valid loss:0.517 valid acc:0.868
# Epoch:99 / 100, train loss:0.033 train_acc:0.994, valid loss:0.575 valid acc:0.859
# Epoch:100 / 100, train loss:0.038 train_acc:0.990, valid loss:0.571 valid acc:0.859
# test acc:0.833

# %%
def get_plot(hist_list, labels, epochs):
    
    colors = ['red',"blue","green","orange"]
    
    fig, ax = plt.subplots(1,2, figsize=(16,4))
    for i, hist in enumerate(hist_list):
        ax[0].plot(range(len(hist['val_loss'])), hist['val_loss'], '-', color = colors[i], label=labels[i])
        
    ax[0].set_title('Evaluation Loss')
    ax[0].set_xlabel('Epochs')
    ax[0].set_ylabel('Loss')
    ax[0].legend()
    
    for i, hist in enumerate(hist_list):
        ax[1].plot(range(len(hist['val_acc'])), hist['val_acc'], '-', color = colors[i], label=labels[i])
        

    ax[1].set_title('Evaluation Acc.')
    ax[1].set_xlabel('Epochs')
    ax[1].set_ylabel('Acc.')
    ax[1].legend()
   
    plt.show()

# %%
print(f"Test acc: model A {acc_a:.3f}, model B {acc_b:.3f}")

get_plot([hista, histb], ["Model A","Model B"], len(hista['val_loss']))
# Out:
# Test acc: model A 0.818, model B 0.833

# %% [markdown]
# ## Q2: Fight overfitting using Dropout
# `(2 points)`
#
#
# **Model C**: Take the `best model` you achieved from Q1, add a `Dropout layer after the input and the hidden layers`. Tune the dropout rate accordingly. `(1 point. Two dropout layers must be added)`
# <br><br>
# Train the  model using the training function. Plot evaluation loss / accuracy vs. epoches from the training histories of all the three models.
# <br><br>
# Write your analysis (as markdowns or in a separate pdf file) on the following: `(1 point)`
# - Is Dropout a good strategy to address overfitting? Do you observe any changes to the learning curve?`(0.5 point)`: *yes, the learning curve becomes smoothier, and it reduces overfitting in Model B and improves test accuracy*
# - How did you determine the dropout rate? `(0.5 point)`: *drop rate usually should not be more than 0.5. You can start with 0.5 and gradually reduce the rate to see which one gives you better performance. If you use high dropout rate, it may take longer to train. Be sure to observe your learning curve to make sure the model converges*

# %%
class linear_model_with_dropout(nn.Module):
    
    # hidden_units is a list which specify the output of each layer
    def __init__(self, input_dim = 784, hidden_units=[100], droprate=0.3):
        
        # initialize parent class
        super(linear_model_with_dropout, self).__init__()
        
        hidden_units = [input_dim] + hidden_units
        
        self.layers = nn.ModuleList([nn.Linear(hidden_units[i], hidden_units[i+1]) for i in range(len(hidden_units)-1)])
        
        self.dropout = nn.Dropout(droprate)
    
    def forward(self, x):
        
        output = self.dropout(x)
        for i, layer in enumerate(self.layers):
            
            output = layer(output)
            
            if i<len(self.layers)-1:   # no activation on the last layer
                output = F.relu(output)
                output = self.dropout(output)
        
        return output

# %%
# dataset

modelc = linear_model_with_dropout(input_dim = 784, 
                                   hidden_units=[512, 10],
                                  droprate = 0.3)
summary(modelc, (24, 784))

optimizer = torch.optim.RMSprop(modelc.parameters(), lr = 0.0005)

acc_c, histc = train_model(modelc, train_dataset, val_dataset, test_dataset, 
                     device, optimizer, epochs = 100)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# linear_model_with_dropout                [24, 10]                  --
# ├─Dropout: 1-1                           [24, 784]                 --
# ├─ModuleList: 1                          --                        --
# │    └─Linear: 2-1                       [24, 512]                 401,920
# ├─Dropout: 1-2                           [24, 512]                 --
# ├─ModuleList: 1                          --                        --
# │    └─Linear: 2-2                       [24, 10]                  5,130
# ==========================================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# Total mult-adds (M): 9.77
# ==========================================================================================
# Input size (MB): 0.08
# Forward/backward pass size (MB): 0.10
# Params size (MB): 1.63
# Estimated Total Size (MB): 1.80
# ==========================================================================================
# Training Start
# Epoch:1 / 100, train loss:1.138 train_acc:0.606, valid loss:0.663 valid acc:0.790
# Epoch:2 / 100, train loss:0.728 train_acc:0.742, valid loss:0.621 valid acc:0.757
# Epoch:3 / 100, train loss:0.651 train_acc:0.759, valid loss:0.542 valid acc:0.817
# Epoch:4 / 100, train loss:0.616 train_acc:0.781, valid loss:0.547 valid acc:0.795
# Epoch:5 / 100, train loss:0.584 train_acc:0.796, valid loss:0.505 valid acc:0.828
# Epoch:6 / 100, train loss:0.565 train_acc:0.796, valid loss:0.472 valid acc:0.839
# Epoch:7 / 100, train loss:0.543 train_acc:0.802, valid loss:0.497 valid acc:0.818
# Epoch:8 / 100, train loss:0.519 train_acc:0.807, valid loss:0.456 valid acc:0.847
# Epoch:9 / 100, train loss:0.506 train_acc:0.811, valid loss:0.443 valid acc:0.852
# Epoch:10 / 100, train loss:0.500 train_acc:0.817, valid loss:0.470 valid acc:0.838
# Epoch:11 / 100, train loss:0.491 train_acc:0.827, valid loss:0.427 valid acc:0.854
# Epoch:12 / 100, train loss:0.478 train_acc:0.825, valid loss:0.510 valid acc:0.820
# Epoch:13 / 100, train loss:0.464 train_acc:0.833, valid loss:0.445 valid acc:0.837
# Epoch:14 / 100, train loss:0.452 train_acc:0.842, valid loss:0.445 valid acc:0.845
# Epoch:15 / 100, train loss:0.449 train_acc:0.833, valid loss:0.426 valid acc:0.839
# Epoch:16 / 100, train loss:0.440 train_acc:0.843, valid loss:0.438 valid acc:0.852
# Epoch:17 / 100, train loss:0.441 train_acc:0.841, valid loss:0.424 valid acc:0.841
# Epoch:18 / 100, train loss:0.438 train_acc:0.837, valid loss:0.441 valid acc:0.846
# Epoch:19 / 100, train loss:0.409 train_acc:0.853, valid loss:0.427 valid acc:0.850
# Epoch:20 / 100, train loss:0.415 train_acc:0.844, valid loss:0.395 valid acc:0.853
# Epoch:21 / 100, train loss:0.411 train_acc:0.855, valid loss:0.406 valid acc:0.858
# Epoch:22 / 100, train loss:0.403 train_acc:0.854, valid loss:0.395 valid acc:0.861
# Epoch:23 / 100, train loss:0.398 train_acc:0.855, valid loss:0.400 valid acc:0.858
# Epoch:24 / 100, train loss:0.396 train_acc:0.857, valid loss:0.401 valid acc:0.857
# Epoch:25 / 100, train loss:0.378 train_acc:0.863, valid loss:0.392 valid acc:0.860
# Epoch:26 / 100, train loss:0.380 train_acc:0.866, valid loss:0.396 valid acc:0.857
# Epoch:27 / 100, train loss:0.380 train_acc:0.858, valid loss:0.408 valid acc:0.851
# Epoch:28 / 100, train loss:0.379 train_acc:0.859, valid loss:0.410 valid acc:0.855
# Epoch:29 / 100, train loss:0.374 train_acc:0.864, valid loss:0.379 valid acc:0.868
# Epoch:30 / 100, train loss:0.356 train_acc:0.869, valid loss:0.418 valid acc:0.858
# Epoch:31 / 100, train loss:0.350 train_acc:0.867, valid loss:0.387 valid acc:0.859
# Epoch:32 / 100, train loss:0.354 train_acc:0.868, valid loss:0.387 valid acc:0.853
# Epoch:33 / 100, train loss:0.344 train_acc:0.874, valid loss:0.384 valid acc:0.865
# Epoch:34 / 100, train loss:0.342 train_acc:0.878, valid loss:0.374 valid acc:0.863
# Epoch:35 / 100, train loss:0.339 train_acc:0.878, valid loss:0.379 valid acc:0.867
# Epoch:36 / 100, train loss:0.336 train_acc:0.874, valid loss:0.381 valid acc:0.861
# Epoch:37 / 100, train loss:0.329 train_acc:0.881, valid loss:0.366 valid acc:0.864
# Epoch:38 / 100, train loss:0.324 train_acc:0.877, valid loss:0.371 valid acc:0.860
# Epoch:39 / 100, train loss:0.319 train_acc:0.875, valid loss:0.377 valid acc:0.860
# Epoch:40 / 100, train loss:0.329 train_acc:0.877, valid loss:0.374 valid acc:0.864
# Epoch:41 / 100, train loss:0.319 train_acc:0.878, valid loss:0.399 valid acc:0.856
# Epoch:42 / 100, train loss:0.319 train_acc:0.882, valid loss:0.380 valid acc:0.866
# Epoch:43 / 100, train loss:0.314 train_acc:0.886, valid loss:0.367 valid acc:0.870
# Epoch:44 / 100, train loss:0.312 train_acc:0.888, valid loss:0.366 valid acc:0.867
# Epoch:45 / 100, train loss:0.305 train_acc:0.887, valid loss:0.372 valid acc:0.867
# Epoch:46 / 100, train loss:0.310 train_acc:0.882, valid loss:0.391 valid acc:0.858
# Epoch:47 / 100, train loss:0.302 train_acc:0.888, valid loss:0.368 valid acc:0.867
# Epoch:48 / 100, train loss:0.294 train_acc:0.889, valid loss:0.362 valid acc:0.870
# Epoch:49 / 100, train loss:0.300 train_acc:0.893, valid loss:0.379 valid acc:0.870
# Epoch:50 / 100, train loss:0.299 train_acc:0.896, valid loss:0.391 valid acc:0.857
# Epoch:51 / 100, train loss:0.290 train_acc:0.893, valid loss:0.395 valid acc:0.856
# Epoch:52 / 100, train loss:0.283 train_acc:0.898, valid loss:0.386 valid acc:0.858
# Epoch:53 / 100, train loss:0.283 train_acc:0.890, valid loss:0.364 valid acc:0.870
# Epoch:54 / 100, train loss:0.275 train_acc:0.899, valid loss:0.371 valid acc:0.870
# Epoch:55 / 100, train loss:0.280 train_acc:0.892, valid loss:0.362 valid acc:0.875
# Epoch:56 / 100, train loss:0.284 train_acc:0.896, valid loss:0.383 valid acc:0.858
# Epoch:57 / 100, train loss:0.276 train_acc:0.895, valid loss:0.368 valid acc:0.871
# Epoch:58 / 100, train loss:0.271 train_acc:0.898, valid loss:0.361 valid acc:0.874
# Epoch:59 / 100, train loss:0.269 train_acc:0.903, valid loss:0.371 valid acc:0.867
# Epoch:60 / 100, train loss:0.264 train_acc:0.900, valid loss:0.373 valid acc:0.864
# Epoch:61 / 100, train loss:0.263 train_acc:0.902, valid loss:0.362 valid acc:0.871
# Epoch:62 / 100, train loss:0.263 train_acc:0.903, valid loss:0.369 valid acc:0.867
# Epoch:63 / 100, train loss:0.256 train_acc:0.903, valid loss:0.364 valid acc:0.871
# Epoch:64 / 100, train loss:0.262 train_acc:0.904, valid loss:0.383 valid acc:0.867
# Epoch:65 / 100, train loss:0.257 train_acc:0.907, valid loss:0.386 valid acc:0.865
# Epoch:66 / 100, train loss:0.254 train_acc:0.904, valid loss:0.370 valid acc:0.868
# Epoch:67 / 100, train loss:0.248 train_acc:0.907, valid loss:0.380 valid acc:0.864
# Epoch:68 / 100, train loss:0.257 train_acc:0.906, valid loss:0.392 valid acc:0.865
# Epoch:69 / 100, train loss:0.250 train_acc:0.907, valid loss:0.368 valid acc:0.871
# Epoch:70 / 100, train loss:0.248 train_acc:0.912, valid loss:0.362 valid acc:0.867
# Epoch:71 / 100, train loss:0.241 train_acc:0.912, valid loss:0.368 valid acc:0.871
# Epoch:72 / 100, train loss:0.235 train_acc:0.913, valid loss:0.373 valid acc:0.874
# Epoch:73 / 100, train loss:0.246 train_acc:0.909, valid loss:0.365 valid acc:0.876
# Epoch:74 / 100, train loss:0.239 train_acc:0.910, valid loss:0.362 valid acc:0.873
# Epoch:75 / 100, train loss:0.244 train_acc:0.906, valid loss:0.379 valid acc:0.868
# Epoch:76 / 100, train loss:0.231 train_acc:0.919, valid loss:0.379 valid acc:0.865
# Epoch:77 / 100, train loss:0.240 train_acc:0.909, valid loss:0.364 valid acc:0.879
# Epoch:78 / 100, train loss:0.231 train_acc:0.914, valid loss:0.365 valid acc:0.871
# Epoch:79 / 100, train loss:0.229 train_acc:0.918, valid loss:0.383 valid acc:0.872
# Epoch:80 / 100, train loss:0.228 train_acc:0.915, valid loss:0.394 valid acc:0.865
# Epoch:81 / 100, train loss:0.229 train_acc:0.915, valid loss:0.376 valid acc:0.872
# Epoch:82 / 100, train loss:0.221 train_acc:0.919, valid loss:0.391 valid acc:0.864
# Epoch:83 / 100, train loss:0.217 train_acc:0.919, valid loss:0.388 valid acc:0.860
# Epoch:84 / 100, train loss:0.221 train_acc:0.918, valid loss:0.373 valid acc:0.870
# Epoch:85 / 100, train loss:0.233 train_acc:0.916, valid loss:0.376 valid acc:0.868
# Epoch:86 / 100, train loss:0.221 train_acc:0.917, valid loss:0.373 valid acc:0.872
# Epoch:87 / 100, train loss:0.221 train_acc:0.916, valid loss:0.371 valid acc:0.867
# Epoch:88 / 100, train loss:0.221 train_acc:0.916, valid loss:0.386 valid acc:0.865
# Epoch:89 / 100, train loss:0.209 train_acc:0.925, valid loss:0.374 valid acc:0.867
# Epoch:90 / 100, train loss:0.222 train_acc:0.923, valid loss:0.369 valid acc:0.866
# Epoch:91 / 100, train loss:0.208 train_acc:0.926, valid loss:0.403 valid acc:0.860
# Epoch:92 / 100, train loss:0.201 train_acc:0.928, valid loss:0.415 valid acc:0.856
# Epoch:93 / 100, train loss:0.204 train_acc:0.922, valid loss:0.394 valid acc:0.869
# Epoch:94 / 100, train loss:0.211 train_acc:0.923, valid loss:0.405 valid acc:0.856
# Epoch:95 / 100, train loss:0.206 train_acc:0.923, valid loss:0.385 valid acc:0.874
# Epoch:96 / 100, train loss:0.202 train_acc:0.927, valid loss:0.386 valid acc:0.872
# Epoch:97 / 100, train loss:0.201 train_acc:0.926, valid loss:0.406 valid acc:0.863
# Epoch:98 / 100, train loss:0.198 train_acc:0.929, valid loss:0.389 valid acc:0.871
# Epoch:99 / 100, train loss:0.198 train_acc:0.924, valid loss:0.392 valid acc:0.862
# Epoch:100 / 100, train loss:0.206 train_acc:0.924, valid loss:0.389 valid acc:0.870
# test acc:0.849

# %%
print(f"Test acc: model A {acc_a:.3f}, model B {acc_b:.3f}, model C {acc_c:.3f}")

get_plot([hista, histb, histc], ["Model A","Model B", "Model B - Dropout"], len(hista['val_loss']))
# Out:
# Test acc: model A 0.818, model B 0.833, model C 0.849

# %% [markdown]
# #** Q.2)**
#
# Dropout is a regularization technique that is used to prevents neural networks from overfitting.
# Using Dropout we modify the network.
# It randomly drops neurons from the neural network during training in each iteration.
# When we drop different sets of neurons, it’s equivalent to training different neural networks.
# The different networks will overfit in different ways, so the net effect of dropout will be to reduce overfitting.
# There is a difference in learning curve, we can see that there is reduction in overfitting.
#
# The default interpretation of the dropout hyperparameter is the probability of training a given node in a layer, where 1.0 means no dropout, and 0.0 means no outputs from the layer.
#
# A good value for dropout in a hidden layer is between 0.5 and 0.8. Input layers use a larger dropout rate, such as of 0.8.
#
# As there is only 1 hidden layer, in this case i have chosen a drop out rate of 0.5
# ALso it can be calculated as, divide the number of nodes in the layer before dropout by the proposed dropout rate and use that as the number of nodes in the new network that uses dropout.

# %% [markdown]
# ## Q3: Optimizer
#
# `(2 point)`
#
# 1. For Q1 and Q2, we use RMSprop (or any other optimizer you prefer). Now let's train the best model you get in Q1 using the following optimizers (for details, check https://pytorch.org/docs/stable/optim.html?highlight=optimizer#torch.optim.Optimizer): `(1 point)`
# - SGD
# - Adagrad
# - RMSProp
# - Adam
#
# 2. Plot the evaluation loss and accuracy curves for each optimizer.
# <br><br>
# 3. Write your analysis (as markdowns) on the following: `(1 point)`
#    - Which optimizer works the best? What makes this optimizer more effective? `(0.5 point)`: *from the learning curves, RMSProp and Adam work better. In particular, Adam produces smooth a learning curver. The main reason is that these two incorporate exponetially smoothed adaptive learning rate. Adam also implements momentum, which soomthes learning curves*
#    - Which has the worst performance? Why does it perform poorly? `(0.5 point)` *SGD performs the worst, because this vanila gradient descent algorithm does not have adaptive learning rate. In this dataset, obviously, features are not equally important.*

# %%
# SGD
modelx = linear_model(input_dim = 784, hidden_units=[512,  10])
summary(modelx, (32, 784))

optimizer = torch.optim.SGD(modelx.parameters(), lr=0.0005)

acc_d, histd = train_model(modelx, train_dataset, val_dataset, test_dataset, device, optimizer, epochs=100)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# linear_model                             [32, 10]                  --
# ├─ModuleList: 1-1                        --                        --
# │    └─Linear: 2-1                       [32, 512]                 401,920
# │    └─Linear: 2-2                       [32, 10]                  5,130
# ==========================================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# Total mult-adds (M): 13.03
# ==========================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 0.13
# Params size (MB): 1.63
# Estimated Total Size (MB): 1.86
# ==========================================================================================
# Training Start
# Epoch:1 / 100, train loss:2.280 train_acc:0.189, valid loss:2.270 valid acc:0.223
# Epoch:2 / 100, train loss:2.269 train_acc:0.222, valid loss:2.259 valid acc:0.252
# Epoch:3 / 100, train loss:2.258 train_acc:0.252, valid loss:2.248 valid acc:0.293
# Epoch:4 / 100, train loss:2.247 train_acc:0.290, valid loss:2.237 valid acc:0.323
# Epoch:5 / 100, train loss:2.236 train_acc:0.319, valid loss:2.226 valid acc:0.349
# Epoch:6 / 100, train loss:2.226 train_acc:0.338, valid loss:2.216 valid acc:0.372
# Epoch:7 / 100, train loss:2.215 train_acc:0.359, valid loss:2.205 valid acc:0.392
# Epoch:8 / 100, train loss:2.205 train_acc:0.378, valid loss:2.195 valid acc:0.402
# Epoch:9 / 100, train loss:2.195 train_acc:0.389, valid loss:2.185 valid acc:0.413
# Epoch:10 / 100, train loss:2.185 train_acc:0.403, valid loss:2.175 valid acc:0.427
# Epoch:11 / 100, train loss:2.175 train_acc:0.419, valid loss:2.165 valid acc:0.441
# Epoch:12 / 100, train loss:2.165 train_acc:0.432, valid loss:2.155 valid acc:0.456
# Epoch:13 / 100, train loss:2.156 train_acc:0.447, valid loss:2.146 valid acc:0.466
# Epoch:14 / 100, train loss:2.146 train_acc:0.458, valid loss:2.136 valid acc:0.484
# Epoch:15 / 100, train loss:2.136 train_acc:0.478, valid loss:2.126 valid acc:0.502
# Epoch:16 / 100, train loss:2.127 train_acc:0.495, valid loss:2.116 valid acc:0.523
# Epoch:17 / 100, train loss:2.117 train_acc:0.509, valid loss:2.107 valid acc:0.533
# Epoch:18 / 100, train loss:2.108 train_acc:0.526, valid loss:2.097 valid acc:0.547
# Epoch:19 / 100, train loss:2.098 train_acc:0.535, valid loss:2.087 valid acc:0.555
# Epoch:20 / 100, train loss:2.089 train_acc:0.544, valid loss:2.078 valid acc:0.565
# Epoch:21 / 100, train loss:2.079 train_acc:0.554, valid loss:2.068 valid acc:0.574
# Epoch:22 / 100, train loss:2.070 train_acc:0.566, valid loss:2.058 valid acc:0.584
# Epoch:23 / 100, train loss:2.060 train_acc:0.571, valid loss:2.049 valid acc:0.590
# Epoch:24 / 100, train loss:2.051 train_acc:0.579, valid loss:2.039 valid acc:0.594
# Epoch:25 / 100, train loss:2.041 train_acc:0.586, valid loss:2.029 valid acc:0.599
# Epoch:26 / 100, train loss:2.032 train_acc:0.592, valid loss:2.020 valid acc:0.606
# Epoch:27 / 100, train loss:2.022 train_acc:0.600, valid loss:2.010 valid acc:0.609
# Epoch:28 / 100, train loss:2.013 train_acc:0.606, valid loss:2.000 valid acc:0.616
# Epoch:29 / 100, train loss:2.003 train_acc:0.608, valid loss:1.991 valid acc:0.621
# Epoch:30 / 100, train loss:1.994 train_acc:0.612, valid loss:1.981 valid acc:0.624
# Epoch:31 / 100, train loss:1.984 train_acc:0.616, valid loss:1.971 valid acc:0.626
# Epoch:32 / 100, train loss:1.975 train_acc:0.621, valid loss:1.961 valid acc:0.633
# Epoch:33 / 100, train loss:1.965 train_acc:0.624, valid loss:1.952 valid acc:0.637
# Epoch:34 / 100, train loss:1.956 train_acc:0.627, valid loss:1.942 valid acc:0.641
# Epoch:35 / 100, train loss:1.946 train_acc:0.630, valid loss:1.932 valid acc:0.644
# Epoch:36 / 100, train loss:1.937 train_acc:0.633, valid loss:1.922 valid acc:0.645
# Epoch:37 / 100, train loss:1.928 train_acc:0.636, valid loss:1.913 valid acc:0.648
# Epoch:38 / 100, train loss:1.918 train_acc:0.638, valid loss:1.903 valid acc:0.652
# Epoch:39 / 100, train loss:1.909 train_acc:0.638, valid loss:1.893 valid acc:0.654
# Epoch:40 / 100, train loss:1.899 train_acc:0.641, valid loss:1.883 valid acc:0.656
# Epoch:41 / 100, train loss:1.889 train_acc:0.641, valid loss:1.873 valid acc:0.658
# Epoch:42 / 100, train loss:1.880 train_acc:0.643, valid loss:1.863 valid acc:0.659
# Epoch:43 / 100, train loss:1.870 train_acc:0.645, valid loss:1.854 valid acc:0.661
# Epoch:44 / 100, train loss:1.861 train_acc:0.645, valid loss:1.844 valid acc:0.663
# Epoch:45 / 100, train loss:1.851 train_acc:0.646, valid loss:1.834 valid acc:0.665
# Epoch:46 / 100, train loss:1.842 train_acc:0.646, valid loss:1.824 valid acc:0.666
# Epoch:47 / 100, train loss:1.832 train_acc:0.644, valid loss:1.814 valid acc:0.668
# Epoch:48 / 100, train loss:1.823 train_acc:0.646, valid loss:1.805 valid acc:0.669
# Epoch:49 / 100, train loss:1.813 train_acc:0.648, valid loss:1.795 valid acc:0.671
# Epoch:50 / 100, train loss:1.804 train_acc:0.651, valid loss:1.785 valid acc:0.672
# Epoch:51 / 100, train loss:1.795 train_acc:0.651, valid loss:1.775 valid acc:0.672
# Epoch:52 / 100, train loss:1.785 train_acc:0.650, valid loss:1.766 valid acc:0.673
# Epoch:53 / 100, train loss:1.776 train_acc:0.651, valid loss:1.756 valid acc:0.674
# Epoch:54 / 100, train loss:1.766 train_acc:0.652, valid loss:1.747 valid acc:0.683
# Epoch:55 / 100, train loss:1.757 train_acc:0.655, valid loss:1.737 valid acc:0.684
# Epoch:56 / 100, train loss:1.748 train_acc:0.654, valid loss:1.727 valid acc:0.683
# Epoch:57 / 100, train loss:1.738 train_acc:0.654, valid loss:1.718 valid acc:0.684
# Epoch:58 / 100, train loss:1.729 train_acc:0.655, valid loss:1.709 valid acc:0.685
# Epoch:59 / 100, train loss:1.720 train_acc:0.655, valid loss:1.699 valid acc:0.688
# Epoch:60 / 100, train loss:1.711 train_acc:0.656, valid loss:1.690 valid acc:0.687
# Epoch:61 / 100, train loss:1.702 train_acc:0.656, valid loss:1.681 valid acc:0.690
# Epoch:62 / 100, train loss:1.693 train_acc:0.656, valid loss:1.671 valid acc:0.690
# Epoch:63 / 100, train loss:1.684 train_acc:0.655, valid loss:1.662 valid acc:0.690
# Epoch:64 / 100, train loss:1.675 train_acc:0.656, valid loss:1.653 valid acc:0.690
# Epoch:65 / 100, train loss:1.666 train_acc:0.655, valid loss:1.644 valid acc:0.690
# Epoch:66 / 100, train loss:1.657 train_acc:0.656, valid loss:1.635 valid acc:0.691
# Epoch:67 / 100, train loss:1.649 train_acc:0.657, valid loss:1.626 valid acc:0.691
# Epoch:68 / 100, train loss:1.639 train_acc:0.659, valid loss:1.617 valid acc:0.691
# Epoch:69 / 100, train loss:1.631 train_acc:0.659, valid loss:1.608 valid acc:0.691
# Epoch:70 / 100, train loss:1.623 train_acc:0.659, valid loss:1.600 valid acc:0.692
# Epoch:71 / 100, train loss:1.614 train_acc:0.658, valid loss:1.591 valid acc:0.693
# Epoch:72 / 100, train loss:1.606 train_acc:0.658, valid loss:1.582 valid acc:0.693
# Epoch:73 / 100, train loss:1.597 train_acc:0.658, valid loss:1.574 valid acc:0.694
# Epoch:74 / 100, train loss:1.590 train_acc:0.659, valid loss:1.565 valid acc:0.694
# Epoch:75 / 100, train loss:1.581 train_acc:0.659, valid loss:1.557 valid acc:0.694
# Epoch:76 / 100, train loss:1.573 train_acc:0.660, valid loss:1.549 valid acc:0.694
# Epoch:77 / 100, train loss:1.565 train_acc:0.660, valid loss:1.540 valid acc:0.694
# Epoch:78 / 100, train loss:1.557 train_acc:0.661, valid loss:1.532 valid acc:0.694
# Epoch:79 / 100, train loss:1.548 train_acc:0.661, valid loss:1.524 valid acc:0.694
# Epoch:80 / 100, train loss:1.541 train_acc:0.661, valid loss:1.516 valid acc:0.694
# Epoch:81 / 100, train loss:1.533 train_acc:0.661, valid loss:1.508 valid acc:0.695
# Epoch:82 / 100, train loss:1.525 train_acc:0.661, valid loss:1.500 valid acc:0.696
# Epoch:83 / 100, train loss:1.517 train_acc:0.661, valid loss:1.492 valid acc:0.696
# Epoch:84 / 100, train loss:1.510 train_acc:0.661, valid loss:1.485 valid acc:0.697
# Epoch:85 / 100, train loss:1.503 train_acc:0.661, valid loss:1.477 valid acc:0.697
# Epoch:86 / 100, train loss:1.496 train_acc:0.661, valid loss:1.470 valid acc:0.698
# Epoch:87 / 100, train loss:1.488 train_acc:0.662, valid loss:1.462 valid acc:0.698
# Epoch:88 / 100, train loss:1.480 train_acc:0.663, valid loss:1.455 valid acc:0.698
# Epoch:89 / 100, train loss:1.474 train_acc:0.664, valid loss:1.447 valid acc:0.698
# Epoch:90 / 100, train loss:1.466 train_acc:0.665, valid loss:1.440 valid acc:0.699
# Epoch:91 / 100, train loss:1.460 train_acc:0.664, valid loss:1.433 valid acc:0.699
# Epoch:92 / 100, train loss:1.452 train_acc:0.664, valid loss:1.426 valid acc:0.699
# Epoch:93 / 100, train loss:1.445 train_acc:0.664, valid loss:1.419 valid acc:0.700
# Epoch:94 / 100, train loss:1.439 train_acc:0.664, valid loss:1.412 valid acc:0.701
# Epoch:95 / 100, train loss:1.432 train_acc:0.666, valid loss:1.405 valid acc:0.700
# Epoch:96 / 100, train loss:1.425 train_acc:0.665, valid loss:1.398 valid acc:0.701
# Epoch:97 / 100, train loss:1.418 train_acc:0.666, valid loss:1.392 valid acc:0.703
# Epoch:98 / 100, train loss:1.412 train_acc:0.667, valid loss:1.385 valid acc:0.704
# Epoch:99 / 100, train loss:1.406 train_acc:0.667, valid loss:1.379 valid acc:0.704
# Epoch:100 / 100, train loss:1.399 train_acc:0.668, valid loss:1.372 valid acc:0.705
# test acc:0.656

# %%
# Adaptive learn
modelx = linear_model(input_dim = 784, hidden_units=[512,  10])
summary(modelx, (32, 784))

optimizer = torch.optim.Adagrad(modelx.parameters(), lr=0.0005)

acc_e, histe = train_model(modelx, train_dataset, val_dataset, test_dataset, device, optimizer, epochs=100)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# linear_model                             [32, 10]                  --
# ├─ModuleList: 1-1                        --                        --
# │    └─Linear: 2-1                       [32, 512]                 401,920
# │    └─Linear: 2-2                       [32, 10]                  5,130
# ==========================================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# Total mult-adds (M): 13.03
# ==========================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 0.13
# Params size (MB): 1.63
# Estimated Total Size (MB): 1.86
# ==========================================================================================
# Training Start
# Epoch:1 / 100, train loss:1.669 train_acc:0.597, valid loss:1.318 valid acc:0.696
# Epoch:2 / 100, train loss:1.220 train_acc:0.677, valid loss:1.083 valid acc:0.704
# Epoch:3 / 100, train loss:1.062 train_acc:0.691, valid loss:0.969 valid acc:0.716
# Epoch:4 / 100, train loss:0.972 train_acc:0.702, valid loss:0.900 valid acc:0.723
# Epoch:5 / 100, train loss:0.915 train_acc:0.708, valid loss:0.852 valid acc:0.741
# Epoch:6 / 100, train loss:0.873 train_acc:0.722, valid loss:0.815 valid acc:0.751
# Epoch:7 / 100, train loss:0.842 train_acc:0.731, valid loss:0.788 valid acc:0.753
# Epoch:8 / 100, train loss:0.815 train_acc:0.743, valid loss:0.761 valid acc:0.752
# Epoch:9 / 100, train loss:0.793 train_acc:0.744, valid loss:0.743 valid acc:0.760
# Epoch:10 / 100, train loss:0.775 train_acc:0.751, valid loss:0.728 valid acc:0.768
# Epoch:11 / 100, train loss:0.758 train_acc:0.760, valid loss:0.712 valid acc:0.765
# Epoch:12 / 100, train loss:0.745 train_acc:0.764, valid loss:0.699 valid acc:0.773
# Epoch:13 / 100, train loss:0.733 train_acc:0.767, valid loss:0.690 valid acc:0.778
# Epoch:14 / 100, train loss:0.721 train_acc:0.768, valid loss:0.679 valid acc:0.785
# Epoch:15 / 100, train loss:0.711 train_acc:0.774, valid loss:0.669 valid acc:0.784
# Epoch:16 / 100, train loss:0.701 train_acc:0.779, valid loss:0.662 valid acc:0.782
# Epoch:17 / 100, train loss:0.694 train_acc:0.775, valid loss:0.656 valid acc:0.787
# Epoch:18 / 100, train loss:0.685 train_acc:0.782, valid loss:0.647 valid acc:0.783
# Epoch:19 / 100, train loss:0.679 train_acc:0.783, valid loss:0.639 valid acc:0.792
# Epoch:20 / 100, train loss:0.671 train_acc:0.784, valid loss:0.633 valid acc:0.794
# Epoch:21 / 100, train loss:0.665 train_acc:0.787, valid loss:0.628 valid acc:0.795
# Epoch:22 / 100, train loss:0.659 train_acc:0.791, valid loss:0.624 valid acc:0.798
# Epoch:23 / 100, train loss:0.653 train_acc:0.792, valid loss:0.617 valid acc:0.797
# Epoch:24 / 100, train loss:0.648 train_acc:0.793, valid loss:0.612 valid acc:0.799
# Epoch:25 / 100, train loss:0.643 train_acc:0.793, valid loss:0.609 valid acc:0.799
# Epoch:26 / 100, train loss:0.639 train_acc:0.795, valid loss:0.605 valid acc:0.798
# Epoch:27 / 100, train loss:0.634 train_acc:0.794, valid loss:0.601 valid acc:0.802
# Epoch:28 / 100, train loss:0.629 train_acc:0.798, valid loss:0.597 valid acc:0.803
# Epoch:29 / 100, train loss:0.624 train_acc:0.800, valid loss:0.594 valid acc:0.802
# Epoch:30 / 100, train loss:0.621 train_acc:0.799, valid loss:0.590 valid acc:0.803
# Epoch:31 / 100, train loss:0.617 train_acc:0.802, valid loss:0.586 valid acc:0.804
# Epoch:32 / 100, train loss:0.614 train_acc:0.801, valid loss:0.585 valid acc:0.808
# Epoch:33 / 100, train loss:0.610 train_acc:0.802, valid loss:0.580 valid acc:0.808
# Epoch:34 / 100, train loss:0.607 train_acc:0.802, valid loss:0.578 valid acc:0.812
# Epoch:35 / 100, train loss:0.603 train_acc:0.805, valid loss:0.576 valid acc:0.809
# Epoch:36 / 100, train loss:0.600 train_acc:0.807, valid loss:0.572 valid acc:0.808
# Epoch:37 / 100, train loss:0.597 train_acc:0.808, valid loss:0.569 valid acc:0.814
# Epoch:38 / 100, train loss:0.595 train_acc:0.809, valid loss:0.567 valid acc:0.810
# Epoch:39 / 100, train loss:0.592 train_acc:0.807, valid loss:0.565 valid acc:0.812
# Epoch:40 / 100, train loss:0.589 train_acc:0.810, valid loss:0.564 valid acc:0.814
# Epoch:41 / 100, train loss:0.586 train_acc:0.811, valid loss:0.562 valid acc:0.815
# Epoch:42 / 100, train loss:0.584 train_acc:0.810, valid loss:0.557 valid acc:0.818
# Epoch:43 / 100, train loss:0.581 train_acc:0.810, valid loss:0.555 valid acc:0.817
# Epoch:44 / 100, train loss:0.578 train_acc:0.812, valid loss:0.553 valid acc:0.816
# Epoch:45 / 100, train loss:0.576 train_acc:0.813, valid loss:0.554 valid acc:0.826
# Epoch:46 / 100, train loss:0.574 train_acc:0.813, valid loss:0.550 valid acc:0.828
# Epoch:47 / 100, train loss:0.571 train_acc:0.814, valid loss:0.550 valid acc:0.827
# Epoch:48 / 100, train loss:0.569 train_acc:0.813, valid loss:0.546 valid acc:0.828
# Epoch:49 / 100, train loss:0.567 train_acc:0.814, valid loss:0.545 valid acc:0.829
# Epoch:50 / 100, train loss:0.566 train_acc:0.813, valid loss:0.543 valid acc:0.829
# Epoch:51 / 100, train loss:0.563 train_acc:0.816, valid loss:0.542 valid acc:0.831
# Epoch:52 / 100, train loss:0.561 train_acc:0.814, valid loss:0.540 valid acc:0.828
# Epoch:53 / 100, train loss:0.559 train_acc:0.814, valid loss:0.538 valid acc:0.832
# Epoch:54 / 100, train loss:0.558 train_acc:0.819, valid loss:0.538 valid acc:0.831
# Epoch:55 / 100, train loss:0.555 train_acc:0.818, valid loss:0.536 valid acc:0.832
# Epoch:56 / 100, train loss:0.553 train_acc:0.818, valid loss:0.534 valid acc:0.830
# Epoch:57 / 100, train loss:0.552 train_acc:0.820, valid loss:0.533 valid acc:0.832
# Epoch:58 / 100, train loss:0.550 train_acc:0.819, valid loss:0.533 valid acc:0.834
# Epoch:59 / 100, train loss:0.549 train_acc:0.820, valid loss:0.529 valid acc:0.832
# Epoch:60 / 100, train loss:0.547 train_acc:0.820, valid loss:0.529 valid acc:0.832
# Epoch:61 / 100, train loss:0.545 train_acc:0.821, valid loss:0.528 valid acc:0.833
# Epoch:62 / 100, train loss:0.543 train_acc:0.821, valid loss:0.527 valid acc:0.833
# Epoch:63 / 100, train loss:0.542 train_acc:0.821, valid loss:0.526 valid acc:0.834
# Epoch:64 / 100, train loss:0.540 train_acc:0.825, valid loss:0.524 valid acc:0.834
# Epoch:65 / 100, train loss:0.540 train_acc:0.823, valid loss:0.523 valid acc:0.835
# Epoch:66 / 100, train loss:0.538 train_acc:0.823, valid loss:0.523 valid acc:0.834
# Epoch:67 / 100, train loss:0.536 train_acc:0.822, valid loss:0.521 valid acc:0.836
# Epoch:68 / 100, train loss:0.535 train_acc:0.823, valid loss:0.520 valid acc:0.835
# Epoch:69 / 100, train loss:0.533 train_acc:0.824, valid loss:0.518 valid acc:0.835
# Epoch:70 / 100, train loss:0.532 train_acc:0.823, valid loss:0.518 valid acc:0.836
# Epoch:71 / 100, train loss:0.531 train_acc:0.824, valid loss:0.517 valid acc:0.837
# Epoch:72 / 100, train loss:0.530 train_acc:0.825, valid loss:0.515 valid acc:0.834
# Epoch:73 / 100, train loss:0.527 train_acc:0.825, valid loss:0.515 valid acc:0.838
# Epoch:74 / 100, train loss:0.527 train_acc:0.827, valid loss:0.514 valid acc:0.836
# Epoch:75 / 100, train loss:0.526 train_acc:0.826, valid loss:0.513 valid acc:0.838
# Epoch:76 / 100, train loss:0.524 train_acc:0.828, valid loss:0.511 valid acc:0.837
# Epoch:77 / 100, train loss:0.522 train_acc:0.825, valid loss:0.511 valid acc:0.840
# Epoch:78 / 100, train loss:0.522 train_acc:0.828, valid loss:0.510 valid acc:0.836
# Epoch:79 / 100, train loss:0.520 train_acc:0.827, valid loss:0.509 valid acc:0.839
# Epoch:80 / 100, train loss:0.519 train_acc:0.827, valid loss:0.508 valid acc:0.840
# Epoch:81 / 100, train loss:0.518 train_acc:0.827, valid loss:0.507 valid acc:0.839
# Epoch:82 / 100, train loss:0.517 train_acc:0.828, valid loss:0.507 valid acc:0.843
# Epoch:83 / 100, train loss:0.516 train_acc:0.829, valid loss:0.506 valid acc:0.841
# Epoch:84 / 100, train loss:0.515 train_acc:0.829, valid loss:0.505 valid acc:0.843
# Epoch:85 / 100, train loss:0.514 train_acc:0.830, valid loss:0.504 valid acc:0.840
# Epoch:86 / 100, train loss:0.513 train_acc:0.829, valid loss:0.503 valid acc:0.842
# Epoch:87 / 100, train loss:0.511 train_acc:0.829, valid loss:0.502 valid acc:0.843
# Epoch:88 / 100, train loss:0.511 train_acc:0.830, valid loss:0.501 valid acc:0.840
# Epoch:89 / 100, train loss:0.509 train_acc:0.830, valid loss:0.501 valid acc:0.842
# Epoch:90 / 100, train loss:0.508 train_acc:0.828, valid loss:0.500 valid acc:0.843
# Epoch:91 / 100, train loss:0.508 train_acc:0.832, valid loss:0.499 valid acc:0.842
# Epoch:92 / 100, train loss:0.507 train_acc:0.831, valid loss:0.499 valid acc:0.842
# Epoch:93 / 100, train loss:0.505 train_acc:0.830, valid loss:0.497 valid acc:0.842
# Epoch:94 / 100, train loss:0.504 train_acc:0.830, valid loss:0.497 valid acc:0.844
# Epoch:95 / 100, train loss:0.504 train_acc:0.832, valid loss:0.497 valid acc:0.843
# Epoch:96 / 100, train loss:0.502 train_acc:0.831, valid loss:0.496 valid acc:0.843
# Epoch:97 / 100, train loss:0.501 train_acc:0.833, valid loss:0.495 valid acc:0.842
# Epoch:98 / 100, train loss:0.501 train_acc:0.832, valid loss:0.495 valid acc:0.844
# Epoch:99 / 100, train loss:0.500 train_acc:0.833, valid loss:0.494 valid acc:0.843
# Epoch:100 / 100, train loss:0.499 train_acc:0.834, valid loss:0.494 valid acc:0.844
# test acc:0.809

# %%
# Adam

modelx = linear_model(input_dim = 784, hidden_units=[512,  10])
summary(modelx, (32, 784))

optimizer = torch.optim.Adam(modelx.parameters(), lr=0.0005)

acc_f, histf = train_model(modelx, train_dataset, val_dataset, test_dataset, device, optimizer, epochs=100)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# linear_model                             [32, 10]                  --
# ├─ModuleList: 1-1                        --                        --
# │    └─Linear: 2-1                       [32, 512]                 401,920
# │    └─Linear: 2-2                       [32, 10]                  5,130
# ==========================================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# Total mult-adds (M): 13.03
# ==========================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 0.13
# Params size (MB): 1.63
# Estimated Total Size (MB): 1.86
# ==========================================================================================
# Training Start
# Epoch:1 / 100, train loss:1.310 train_acc:0.613, valid loss:0.769 valid acc:0.744
# Epoch:2 / 100, train loss:0.748 train_acc:0.732, valid loss:0.621 valid acc:0.778
# Epoch:3 / 100, train loss:0.632 train_acc:0.777, valid loss:0.578 valid acc:0.802
# Epoch:4 / 100, train loss:0.570 train_acc:0.799, valid loss:0.512 valid acc:0.835
# Epoch:5 / 100, train loss:0.518 train_acc:0.823, valid loss:0.478 valid acc:0.836
# Epoch:6 / 100, train loss:0.489 train_acc:0.829, valid loss:0.478 valid acc:0.841
# Epoch:7 / 100, train loss:0.459 train_acc:0.840, valid loss:0.470 valid acc:0.839
# Epoch:8 / 100, train loss:0.440 train_acc:0.846, valid loss:0.445 valid acc:0.852
# Epoch:9 / 100, train loss:0.422 train_acc:0.849, valid loss:0.429 valid acc:0.849
# Epoch:10 / 100, train loss:0.404 train_acc:0.863, valid loss:0.427 valid acc:0.855
# Epoch:11 / 100, train loss:0.394 train_acc:0.862, valid loss:0.443 valid acc:0.854
# Epoch:12 / 100, train loss:0.383 train_acc:0.864, valid loss:0.427 valid acc:0.844
# Epoch:13 / 100, train loss:0.369 train_acc:0.868, valid loss:0.457 valid acc:0.845
# Epoch:14 / 100, train loss:0.357 train_acc:0.879, valid loss:0.422 valid acc:0.859
# Epoch:15 / 100, train loss:0.342 train_acc:0.882, valid loss:0.425 valid acc:0.856
# Epoch:16 / 100, train loss:0.336 train_acc:0.882, valid loss:0.413 valid acc:0.853
# Epoch:17 / 100, train loss:0.321 train_acc:0.890, valid loss:0.433 valid acc:0.840
# Epoch:18 / 100, train loss:0.333 train_acc:0.882, valid loss:0.443 valid acc:0.851
# Epoch:19 / 100, train loss:0.305 train_acc:0.894, valid loss:0.406 valid acc:0.860
# Epoch:20 / 100, train loss:0.295 train_acc:0.902, valid loss:0.440 valid acc:0.856
# Epoch:21 / 100, train loss:0.289 train_acc:0.902, valid loss:0.423 valid acc:0.849
# Epoch:22 / 100, train loss:0.276 train_acc:0.912, valid loss:0.426 valid acc:0.857
# Epoch:23 / 100, train loss:0.267 train_acc:0.910, valid loss:0.427 valid acc:0.855
# Epoch:24 / 100, train loss:0.263 train_acc:0.913, valid loss:0.406 valid acc:0.860
# Epoch:25 / 100, train loss:0.255 train_acc:0.913, valid loss:0.446 valid acc:0.856
# Epoch:26 / 100, train loss:0.250 train_acc:0.914, valid loss:0.424 valid acc:0.847
# Epoch:27 / 100, train loss:0.241 train_acc:0.919, valid loss:0.427 valid acc:0.861
# Epoch:28 / 100, train loss:0.246 train_acc:0.915, valid loss:0.412 valid acc:0.858
# Epoch:29 / 100, train loss:0.240 train_acc:0.919, valid loss:0.403 valid acc:0.856
# Epoch:30 / 100, train loss:0.224 train_acc:0.929, valid loss:0.431 valid acc:0.857
# Epoch:31 / 100, train loss:0.228 train_acc:0.922, valid loss:0.473 valid acc:0.845
# Epoch:32 / 100, train loss:0.233 train_acc:0.918, valid loss:0.450 valid acc:0.854
# Epoch:33 / 100, train loss:0.209 train_acc:0.929, valid loss:0.410 valid acc:0.857
# Epoch:34 / 100, train loss:0.202 train_acc:0.934, valid loss:0.422 valid acc:0.862
# Epoch:35 / 100, train loss:0.193 train_acc:0.938, valid loss:0.414 valid acc:0.858
# Epoch:36 / 100, train loss:0.191 train_acc:0.940, valid loss:0.419 valid acc:0.862
# Epoch:37 / 100, train loss:0.188 train_acc:0.938, valid loss:0.431 valid acc:0.859
# Epoch:38 / 100, train loss:0.178 train_acc:0.946, valid loss:0.421 valid acc:0.860
# Epoch:39 / 100, train loss:0.176 train_acc:0.941, valid loss:0.416 valid acc:0.866
# Epoch:40 / 100, train loss:0.169 train_acc:0.948, valid loss:0.415 valid acc:0.862
# Epoch:41 / 100, train loss:0.166 train_acc:0.949, valid loss:0.425 valid acc:0.860
# Epoch:42 / 100, train loss:0.180 train_acc:0.941, valid loss:0.441 valid acc:0.854
# Epoch:43 / 100, train loss:0.166 train_acc:0.943, valid loss:0.457 valid acc:0.856
# Epoch:44 / 100, train loss:0.151 train_acc:0.955, valid loss:0.431 valid acc:0.864
# Epoch:45 / 100, train loss:0.150 train_acc:0.955, valid loss:0.458 valid acc:0.856
# Epoch:46 / 100, train loss:0.150 train_acc:0.954, valid loss:0.425 valid acc:0.868
# Epoch:47 / 100, train loss:0.150 train_acc:0.953, valid loss:0.424 valid acc:0.864
# Epoch:48 / 100, train loss:0.138 train_acc:0.957, valid loss:0.426 valid acc:0.867
# Epoch:49 / 100, train loss:0.132 train_acc:0.960, valid loss:0.445 valid acc:0.861
# Epoch:50 / 100, train loss:0.134 train_acc:0.959, valid loss:0.456 valid acc:0.856
# Epoch:51 / 100, train loss:0.131 train_acc:0.959, valid loss:0.438 valid acc:0.865
# Epoch:52 / 100, train loss:0.128 train_acc:0.963, valid loss:0.432 valid acc:0.867
# Epoch:53 / 100, train loss:0.119 train_acc:0.965, valid loss:0.453 valid acc:0.859
# Epoch:54 / 100, train loss:0.119 train_acc:0.965, valid loss:0.462 valid acc:0.859
# Epoch:55 / 100, train loss:0.120 train_acc:0.968, valid loss:0.446 valid acc:0.865
# Epoch:56 / 100, train loss:0.113 train_acc:0.968, valid loss:0.458 valid acc:0.865
# Epoch:57 / 100, train loss:0.123 train_acc:0.961, valid loss:0.466 valid acc:0.857
# Epoch:58 / 100, train loss:0.110 train_acc:0.966, valid loss:0.450 valid acc:0.868
# Epoch:59 / 100, train loss:0.105 train_acc:0.970, valid loss:0.444 valid acc:0.866
# Epoch:60 / 100, train loss:0.103 train_acc:0.972, valid loss:0.454 valid acc:0.867
# Epoch:61 / 100, train loss:0.106 train_acc:0.969, valid loss:0.462 valid acc:0.869
# Epoch:62 / 100, train loss:0.095 train_acc:0.977, valid loss:0.471 valid acc:0.857
# Epoch:63 / 100, train loss:0.090 train_acc:0.976, valid loss:0.463 valid acc:0.863
# Epoch:64 / 100, train loss:0.094 train_acc:0.974, valid loss:0.486 valid acc:0.863
# Epoch:65 / 100, train loss:0.087 train_acc:0.980, valid loss:0.481 valid acc:0.864
# Epoch:66 / 100, train loss:0.090 train_acc:0.977, valid loss:0.481 valid acc:0.865
# Epoch:67 / 100, train loss:0.086 train_acc:0.977, valid loss:0.493 valid acc:0.859
# Epoch:68 / 100, train loss:0.088 train_acc:0.978, valid loss:0.494 valid acc:0.863
# Epoch:69 / 100, train loss:0.080 train_acc:0.982, valid loss:0.481 valid acc:0.865
# Epoch:70 / 100, train loss:0.075 train_acc:0.983, valid loss:0.461 valid acc:0.865
# Epoch:71 / 100, train loss:0.070 train_acc:0.985, valid loss:0.473 valid acc:0.866
# Epoch:72 / 100, train loss:0.070 train_acc:0.983, valid loss:0.474 valid acc:0.869
# Epoch:73 / 100, train loss:0.073 train_acc:0.983, valid loss:0.478 valid acc:0.856
# Epoch:74 / 100, train loss:0.072 train_acc:0.983, valid loss:0.480 valid acc:0.865
# Epoch:75 / 100, train loss:0.069 train_acc:0.984, valid loss:0.477 valid acc:0.865
# Epoch:76 / 100, train loss:0.067 train_acc:0.984, valid loss:0.492 valid acc:0.869
# Epoch:77 / 100, train loss:0.062 train_acc:0.988, valid loss:0.488 valid acc:0.865
# Epoch:78 / 100, train loss:0.064 train_acc:0.985, valid loss:0.492 valid acc:0.865
# Epoch:79 / 100, train loss:0.063 train_acc:0.984, valid loss:0.491 valid acc:0.868
# Epoch:80 / 100, train loss:0.063 train_acc:0.987, valid loss:0.506 valid acc:0.864
# Epoch:81 / 100, train loss:0.062 train_acc:0.987, valid loss:0.510 valid acc:0.866
# Epoch:82 / 100, train loss:0.055 train_acc:0.988, valid loss:0.519 valid acc:0.864
# Epoch:83 / 100, train loss:0.061 train_acc:0.984, valid loss:0.536 valid acc:0.865
# Epoch:84 / 100, train loss:0.067 train_acc:0.981, valid loss:0.506 valid acc:0.871
# Epoch:85 / 100, train loss:0.060 train_acc:0.987, valid loss:0.492 valid acc:0.868
# Epoch:86 / 100, train loss:0.055 train_acc:0.988, valid loss:0.514 valid acc:0.866
# Epoch:87 / 100, train loss:0.058 train_acc:0.985, valid loss:0.508 valid acc:0.868
# Epoch:88 / 100, train loss:0.055 train_acc:0.986, valid loss:0.507 valid acc:0.865
# Epoch:89 / 100, train loss:0.054 train_acc:0.989, valid loss:0.519 valid acc:0.866
# Epoch:90 / 100, train loss:0.048 train_acc:0.991, valid loss:0.532 valid acc:0.864
# Epoch:91 / 100, train loss:0.043 train_acc:0.993, valid loss:0.516 valid acc:0.869
# Epoch:92 / 100, train loss:0.041 train_acc:0.993, valid loss:0.521 valid acc:0.859
# Epoch:93 / 100, train loss:0.042 train_acc:0.992, valid loss:0.524 valid acc:0.862
# Epoch:94 / 100, train loss:0.040 train_acc:0.993, valid loss:0.529 valid acc:0.865
# Epoch:95 / 100, train loss:0.038 train_acc:0.994, valid loss:0.561 valid acc:0.865
# Epoch:96 / 100, train loss:0.039 train_acc:0.992, valid loss:0.528 valid acc:0.865
# Epoch:97 / 100, train loss:0.040 train_acc:0.994, valid loss:0.532 valid acc:0.862
# Epoch:98 / 100, train loss:0.050 train_acc:0.989, valid loss:0.526 valid acc:0.865
# Epoch:99 / 100, train loss:0.045 train_acc:0.990, valid loss:0.536 valid acc:0.865
# Epoch:100 / 100, train loss:0.035 train_acc:0.995, valid loss:0.541 valid acc:0.866
# test acc:0.835

# %%
#plot

print(f"Test acc: SGD {acc_d:.3f}, Adagrad {acc_e:.3f}, RMSprop {acc_b:.3f}, Adam {acc_f:.3f} ")

get_plot([histb, histd, histe, histf], ["RMSprop", "SGD", 'Adagrad','Adam'], len(histb['val_loss']))
# Out:
# Test acc: SGD 0.656, Adagrad 0.809, RMSprop 0.833, Adam 0.835

# %% [markdown]
# ## Q3: Bonus
#
# `(2 points)`
#
# In linear regression, we can check coefficients to understand what features are sensitive to predictions. Similarly, here With `Model C`, we'd like to understand what regions of a picture are sensitive to the final prediction. Could you find a way to identify such regions in each of the following images? You can highligh these regions by overlapping a heatmap on the original images. (Hint, think about gradients)
#
#
# *Basic idea:
# We can calculate gradients of loss with regard to inputs. If a pixel has a large gradient, any changes to it may change the loss dramatically. This allows to identify the sensitive areas.*

# %%
batch_size = 6

test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
imgs, labels = next(iter(test_loader))
plt.figure(figsize=(15,10))
grid = torchvision.utils.make_grid(nrow=batch_size, ncols=1, tensor=imgs)
print(f"image tensor: {imgs.shape}")
print(f"class labels: {labels}")
plt.imshow(np.transpose(grid, axes=(1,2,0)), cmap='gray');
# Out:
# image tensor: torch.Size([6, 1, 28, 28])
# class labels: tensor([9, 2, 1, 1, 6, 1])

# %%
modelc.eval()
x = torch.tensor(imgs, requires_grad=True)
outputs = modelc(x.view(batch_size, -1))  
criterion = nn.CrossEntropyLoss()
loss = criterion(outputs, labels.long())
# Out:
# linear_model_with_dropout(
#   (layers): ModuleList(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): Linear(in_features=512, out_features=10, bias=True)
#   )
#   (dropout): Dropout(p=0.3, inplace=False)
# )
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).

# %%
optimizer.zero_grad()

loss.backward()
g = x.grad.cpu().numpy()
g1 = np.squeeze(np.abs(g))
g1.shape
# Out:
# (6, 28, 28)

# %%
img = imgs.cpu().numpy().squeeze()
fig, axes = plt.subplots(1, batch_size, figsize=(15,10))

for i in range(batch_size):
    
    axes[i].imshow(np.squeeze(img[i]), alpha = 0.3, cmap='Greys')
    hm = axes[i].imshow(g1[i], alpha = 0.5, cmap='Reds')
    
plt.show()
